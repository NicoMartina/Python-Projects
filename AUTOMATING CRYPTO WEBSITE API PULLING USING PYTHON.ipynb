# %% [markdown]
# AUTOMATING CRYPTO WEBSITE API PULLING USING PYTHON

# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 

parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  #print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd


#This allows you to see all the columns, not just like 15
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
#This normalizes the data and makes it all pretty in a dataframe

df = pd.json_normalize(data['data'])
df['timestamp'] = pd.to_datetime('now')
df
# Out:
#       id          name symbol          slug  num_market_pairs  \
# 0      1       Bitcoin    BTC       bitcoin             10351
# 1   1027      Ethereum    ETH      ethereum              7138
# 2    825        Tether   USDT        tether             57304
# 3     52           XRP    XRP           xrp               997
# 4   1839           BNB    BNB           bnb              1521
# 5   3408      USD Coin   USDC      usd-coin             13382
# 6   2010       Cardano    ADA       cardano               877
# 7   5426        Solana    SOL        solana               489
# 8     74      Dogecoin   DOGE      dogecoin               747
# 9   3890       Polygon  MATIC       polygon               779
# 10  1958          TRON    TRX          tron               790
# 11     2      Litecoin    LTC      litecoin               950
# 12  6636      Polkadot    DOT  polkadot-new               534
# 13  5805     Avalanche   AVAX     avalanche               467
# 14  1831  Bitcoin Cash    BCH  bitcoin-cash               732
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2013-08-04T00:00:00.000Z
# 4   2017-07-25T00:00:00.000Z
# 5   2018-10-08T00:00:00.000Z
# 6   2017-10-01T00:00:00.000Z
# 7   2020-04-10T00:00:00.000Z
# 8   2013-12-15T00:00:00.000Z
# 9   2019-04-28T00:00:00.000Z
# 10  2017-09-13T00:00:00.000Z
# 11  2013-04-28T00:00:00.000Z
# 12  2020-08-19T00:00:00.000Z
# 13  2020-07-13T00:00:00.000Z
# 14  2017-07-23T00:00:00.000Z
#
#                                                  tags    max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1   [pos, smart-contracts, ethereum-ecosystem, coi...           NaN
# 2   [payments, stablecoin, asset-backed-stablecoin...           NaN
# 3   [medium-of-exchange, enterprise-solutions, arr...  1.000000e+11
# 4   [marketplace, centralized-exchange, payments, ...           NaN
# 5   [medium-of-exchange, stablecoin, asset-backed-...           NaN
# 6   [dpos, pos, platform, research, smart-contract...  4.500000e+10
# 7   [pos, platform, solana-ecosystem, cms-holdings...           NaN
# 8   [mineable, pow, scrypt, medium-of-exchange, me...           NaN
# 9   [pos, platform, enterprise-solutions, zero-kno...  1.000000e+10
# 10  [media, payments, tron-ecosystem, sec-security...           NaN
# 11        [mineable, pow, scrypt, medium-of-exchange]  8.400000e+07
# 12  [substrate, polkadot, binance-chain, polkadot-...           NaN
# 13  [defi, smart-contracts, three-arrows-capital-p...  7.200000e+08
# 14  [mineable, pow, sha-256, marketplace, medium-o...  2.100000e+07
#
#     circulating_supply  total_supply  infinite_supply  platform  cmc_rank  \
# 0         1.943439e+07  1.943439e+07            False       NaN         1
# 1         1.201960e+08  1.201960e+08             True       NaN         2
# 2         8.377544e+10  8.670779e+10             True       NaN         3
# 3         5.254409e+10  9.998862e+10            False       NaN         4
# 4         1.538570e+08  1.538570e+08            False       NaN         5
# 5         2.697058e+10  2.697058e+10            False       NaN         6
# 6         3.498675e+10  3.599913e+10            False       NaN         7
# 7         4.027384e+08  5.527979e+08             True       NaN         8
# 8         1.402475e+11  1.402475e+11             True       NaN         9
# 9         9.319469e+09  1.000000e+10            False       NaN        10
# 10        8.972855e+10  8.972865e+10             True       NaN        11
# 11        7.340145e+07  8.400000e+07            False       NaN        12
# 12        1.206791e+09  1.336270e+09             True       NaN        13
# 13        3.458846e+08  4.326041e+08            False       NaN        14
# 14        1.945354e+07  1.945354e+07            False       NaN        15
#
#     self_reported_circulating_supply  self_reported_market_cap tvl_ratio  \
# 0                                NaN                       NaN      None
# 1                                NaN                       NaN      None
# 2                                NaN                       NaN      None
# 3                                NaN                       NaN      None
# 4                                NaN                       NaN      None
# 5                                NaN                       NaN      None
# 6                                NaN                       NaN      None
# 7                                NaN                       NaN      None
# 8                                NaN                       NaN      None
# 9                                NaN                       NaN      None
# 10                      7.165966e+10              5.791335e+09      None
# 11                               NaN                       NaN      None
# 12                               NaN                       NaN      None
# 13                               NaN                       NaN      None
# 14                               NaN                       NaN      None
#
#                 last_updated  quote.USD.price  quote.USD.volume_24h  \
# 0   2023-07-20T08:20:00.000Z     30186.054795          9.045446e+10
# 1   2023-07-20T08:20:00.000Z      1912.661483          8.751541e+09
# 2   2023-07-20T08:20:00.000Z         1.000204          4.853620e+10
# 3   2023-07-20T08:20:00.000Z         0.821007          2.277244e+10
# 4   2023-07-20T08:20:00.000Z       244.024686          4.339714e+08
# 5   2023-07-20T08:20:00.000Z         1.000170          2.868757e+09
# 6   2023-07-20T08:20:00.000Z         0.326855          4.840341e+08
# 7   2023-07-20T08:20:00.000Z        26.923345          6.285217e+08
# 8   2023-07-20T08:20:00.000Z         0.071076          6.298067e+08
# 9   2023-07-20T08:20:00.000Z         0.780005          3.305176e+08
# 10  2023-07-20T08:20:00.000Z         0.080817          1.641948e+08
# 11  2023-07-20T08:20:00.000Z        93.820657          4.610376e+08
# 12  2023-07-20T08:20:00.000Z         5.347079          2.893013e+08
# 13  2023-07-20T08:20:00.000Z        14.316539          1.239235e+08
# 14  2023-07-20T08:20:00.000Z       247.489905          2.424275e+08
#
#     quote.USD.volume_change_24h  quote.USD.percent_change_1h  \
# 0                      573.0485                     0.135515
# 1                       50.8433                     0.188360
# 2                      117.4086                     0.006276
# 3                      574.3446                    -0.021246
# 4                      -37.9489                     0.122518
# 5                        0.3520                     0.022694
# 6                       39.4000                     0.451828
# 7                       -4.1291                     0.229722
# 8                      123.4211                     0.814146
# 9                       -0.5823                     1.138057
# 10                       5.8655                    -0.105268
# 11                      -1.3993                     0.812146
# 12                     134.5383                     1.072235
# 13                      -2.6535                     0.691293
# 14                     -45.8507                     0.725130
#
#     quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 0                       0.661975                    -0.626574
# 1                       0.241030                     2.193820
# 2                       0.008417                     0.025117
# 3                       4.713788                    73.814918
# 4                       0.813775                    -0.374033
# 5                       0.018691                     0.015527
# 6                       3.816013                    13.898699
# 7                       3.096197                    23.403029
# 8                       3.190049                     9.536919
# 9                       4.958216                     7.225411
# 10                      1.531075                     3.689387
# 11                      1.058500                    -6.285031
# 12                      2.775027                     3.432594
# 13                      2.643833                     9.422423
# 14                      0.764181                   -12.796484
#
#     quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 0                      12.739010                     11.512547
# 1                      10.721400                      5.324507
# 2                       0.019666                     -0.015792
# 3                      68.836317                     74.942157
# 4                       1.340520                    -21.647580
# 5                      -0.011388                      0.020580
# 6                      26.454891                    -10.503170
# 7                      69.482331                     32.656924
# 8                      14.728002                     -3.531722
# 9                      28.500182                    -11.047082
# 10                     17.270803                     11.610827
# 11                     21.838712                      0.811833
# 12                     19.543250                     -0.738310
# 13                     25.598400                     -2.094827
# 14                    132.406414                    113.541670
#
#     quote.USD.percent_change_90d  quote.USD.market_cap  \
# 0                       7.319531          5.866477e+11
# 1                      -0.664865          2.298944e+11
# 2                       0.005466          8.379252e+10
# 3                      74.314947          4.313905e+10
# 4                     -26.203486          3.754491e+10
# 5                       0.004328          2.697516e+10
# 6                     -19.144347          1.143560e+10
# 7                      21.297522          1.084306e+10
# 8                     -15.581920          9.968183e+09
# 9                     -25.546806          7.269231e+09
# 10                     23.436981          7.251613e+09
# 11                      4.373948          6.886572e+09
# 12                    -12.368530          6.452806e+09
# 13                    -21.102730          4.951870e+09
# 14                    100.844017          4.814554e+09
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                          48.3040                        6.339072e+11
# 1                          18.9327                        2.298944e+11
# 2                           6.8996                        8.672546e+10
# 3                           3.5522                        8.210066e+10
# 4                           3.0915                        3.754491e+10
# 5                           2.2212                        2.697516e+10
# 6                           0.9416                        1.470848e+10
# 7                           0.8928                        1.488317e+10
# 8                           0.8209                        9.968183e+09
# 9                           0.5986                        7.800049e+09
# 10                          0.5972                        7.251621e+09
# 11                          0.5671                        7.880935e+09
# 12                          0.5313                        7.145140e+09
# 13                          0.4077                        1.030791e+10
# 14                          0.3964                        5.197288e+09
#
#    quote.USD.tvl    quote.USD.last_updated  platform.id platform.name  \
# 0           None  2023-07-20T08:20:00.000Z          NaN           NaN
# 1           None  2023-07-20T08:20:00.000Z          NaN           NaN
# 2           None  2023-07-20T08:20:00.000Z       1027.0      Ethereum
# 3           None  2023-07-20T08:20:00.000Z          NaN           NaN
# 4           None  2023-07-20T08:20:00.000Z          NaN           NaN
# 5           None  2023-07-20T08:20:00.000Z       1027.0      Ethereum
# 6           None  2023-07-20T08:20:00.000Z          NaN           NaN
# 7           None  2023-07-20T08:20:00.000Z          NaN           NaN
# 8           None  2023-07-20T08:20:00.000Z          NaN           NaN
# 9           None  2023-07-20T08:20:00.000Z          NaN           NaN
# 10          None  2023-07-20T08:20:00.000Z          NaN           NaN
# 11          None  2023-07-20T08:20:00.000Z          NaN           NaN
# 12          None  2023-07-20T08:20:00.000Z          NaN           NaN
# 13          None  2023-07-20T08:20:00.000Z          NaN           NaN
# 14          None  2023-07-20T08:20:00.000Z          NaN           NaN
#
#    platform.symbol platform.slug                      platform.token_address  \
# 0              NaN           NaN                                         NaN
# 1              NaN           NaN                                         NaN
# 2              ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3              NaN           NaN                                         NaN
# 4              NaN           NaN                                         NaN
# 5              ETH      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 6              NaN           NaN                                         NaN
# 7              NaN           NaN                                         NaN
# 8              NaN           NaN                                         NaN
# 9              NaN           NaN                                         NaN
# 10             NaN           NaN                                         NaN
# 11             NaN           NaN                                         NaN
# 12             NaN           NaN                                         NaN
# 13             NaN           NaN                                         NaN
# 14             NaN           NaN                                         NaN
#
#                     timestamp
# 0  2023-07-20 08:22:27.523393
# 1  2023-07-20 08:22:27.523393
# 2  2023-07-20 08:22:27.523393
# 3  2023-07-20 08:22:27.523393
# 4  2023-07-20 08:22:27.523393
# 5  2023-07-20 08:22:27.523393
# 6  2023-07-20 08:22:27.523393
# 7  2023-07-20 08:22:27.523393
# 8  2023-07-20 08:22:27.523393
# 9  2023-07-20 08:22:27.523393
# 10 2023-07-20 08:22:27.523393
# 11 2023-07-20 08:22:27.523393
# 12 2023-07-20 08:22:27.523393
# 13 2023-07-20 08:22:27.523393
# 14 2023-07-20 08:22:27.523393

# %%
def api_runner():
    global df
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
    
    parameters = {
      'start':'1',
      'limit':'15',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
    }

    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
      #print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)

    
    
    #  keep it in a dataframe
    df2 = pd.json_normalize(data['data'])
    df2['Timestamp'] = pd.to_datetime('now')
    df = df.append(df2)

# %%
import os 
from time import time
from time import sleep

for i in range(333):
    api_runner()
    print('API Runner completed')
    sleep(60) #sleep for 1 minute
exit()
# Out:
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\STARTK~1\AppData\Local\Temp/ipykernel_25812/314683833.py in <module>
#       6     api_runner()
#       7     print('API Runner completed')
# ----> 8     sleep(60) #sleep for 1 minute
#       9 exit()
#
# KeyboardInterrupt:

# %%
df72 = pd.read_csv(r'C:\Users\nicof\OneDrive\Documents\Python Scripts\API.csv')
df72

# %%
df

# %%
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
df

# %%
df3 = df.groupby('name', sort=False)[['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d']].mean()
df3

# %%
df4 = df3.stack()
df4

# %%
type(df4)

# %%
df5 = df4.to_frame(name='values')
df5

# %%
df5.count()

# %%
index = pd.Index(range(90))

df6 = df5.set_index(index)
df6

# %%
df7 = df6.rename(columns={'level_1': 'percent_change'})
df7

# %%
df7['percent_change'] = df7['percent_change'].replace(['quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d'],['24h','7d','30d','60d','90d'])
df7

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.catplot(x='percent_change', y='values', hue='name', data=df7, kind='point')

# %%
# Now to do something much simpler
# we are going to create a dataframe with the columns we want

df10 = df[['name','quote.USD.price','timestamp']]
df10 = df10.query("name == 'Bitcoin'")
df10

# %%
sns.set_theme(style="darkgrid")

sns.lineplot(x='timestamp', y='quote.USD.price', data = df10)
